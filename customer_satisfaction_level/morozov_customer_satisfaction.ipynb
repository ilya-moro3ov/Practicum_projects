# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет, меня зовут Александр Куимов. Я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь реагировать на мои комментарии своими по шаблону, показанному чуть ниже. Это нужно, чтобы не создавалась путаница😉
#
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> В такой цветовой ячейке я прошу тебя оставлять свои комментарии. Если исправляешь проект на второй итерации и выше, не забывай пожалуйста указывать номер итерации, например, "Комментарий студента v.2".
# </div>
#
# <br/>
#
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе датасаентистом. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Привет, Александр! Спасибо за ревью, комментарии и вопросы буду оставлять в подобных ячейках)
# </div>
#
# <br/>

# %% [markdown]
# # Описание проекта

# %% [markdown]
# HR-аналитики компании «Работа с заботой» помогают бизнесу оптимизировать управление персоналом: бизнес предоставляет данные, а аналитики предлагают, как избежать финансовых потерь и оттока сотрудников. В этом HR-аналитикам пригодится машинное обучение, с помощью которого получится быстрее и точнее отвечать на вопросы бизнеса.
# Компания предоставила данные с характеристиками сотрудников компании. Среди них — уровень удовлетворённости сотрудника работой в компании. Эту информацию получили из форм обратной связи: сотрудники заполняют тест-опросник, и по его результатам рассчитывается доля их удовлетворённости от 0 до 1, где 0 — совершенно неудовлетворён, 1 — полностью удовлетворён.
# Собирать данные такими опросниками не так легко: компания большая, и всех сотрудников надо сначала оповестить об опросе, а затем проследить, что все его прошли.

# %% [markdown]
# # Цель исследования

# %% [markdown]
# **1. Построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.**
#
# Почему бизнесу это важно: удовлетворённость работой напрямую влияет на отток сотрудников. А предсказание оттока — одна из важнейших задач HR-аналитиков. Внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник.
#
# **2. Построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.**

# %% [markdown]
# # Ход исследования

# %% [markdown]
# **Задача 1: предсказание уровня удовлетворённости сотрудника**
#
# - Шаг 1. Загрузка данных.
# - Шаг 2. Предобработка данных: изучим данные и сделаем выводы. При необходимости выполним предобработку. Если есть пропуски, заполним их в пайплайне.
# - Шаг 3. Исследовательский анализ данных: исследуем все признаки и сделаем выводы о том, как их нужно подготовить.
# - Шаг 4. Подготовка данных: выполним в пайплайне, дополнив пайплайн шага предобработки. При кодировании учитем особенности признаков и моделей и используем как минимум два кодировщика.
# - Шаг 5. Обучение моделей: обучите как минимум две модели. Возьмем одну линейную модель, а в качестве второй — дерево решений. Подберем гиперпараметры как минимум для одной модели с помощью одного из известных инструментов. Выберим лучшую модель и проверим её качество. Выбор сделаем на основе новой метрики — SMAPE (англ. symmetric mean absolute percentage error, «симметричное среднее абсолютное процентное отклонение»). Напишим функцию, которая принимает на вход массивы NumPy или объекты Series в pandas и возвращает значение метрики SMAPE. Используем эту метрику при подборе гиперпараметров и оценке качества моделей. Критерий успеха: SMAPE ≤15 на тестовой выборке. В решении сохраним работу со всеми моделями, которые опробовали. Сделаем выводы.
# - Шаг 6. Оформление выводов: сделаем промежуточные выводы о том, какая модель справилась лучше и почему.
#
# **Задача 2: предсказание увольнения сотрудника из компании**
#
# - Шаг 1. Загрузка данных.
# - Шаг 2. Предобработка данных: изучим данные и при необходимости выполним предобработку. Если есть пропуски, заполним их в пайплайне.
# - Шаг 3. Исследовательский анализ данных:
#     - Проведем исследовательский анализ данных.
#     - Составим портрет «уволившегося сотрудника». (Например, можно узнать, в каком отделе с большей вероятностью работает уволившийся сотрудник и какой у него уровень загруженности. Также можно сравнить среднее значение зарплаты ушедших сотрудников с теми, кто остался в компании).
#     - Проверим утверждение аналитиков, что уровень удовлетворённости сотрудника работой в компании влияет на то, уволится ли сотрудник: визуализируем и сравним распределения признака job_satisfaction_rate для ушедших и оставшихся сотрудников. Используем данные с обоими целевыми признаками тестовой выборки.
# - Шаг 4. Добавление нового входного признака: допустим, job_satisfaction_rate и quit действительно связаны и мы получили необходимое значение метрики в первой задаче. Тогда добавим job_satisfaction_rate, предсказанный лучшей моделью первой задачи, к входным признакам второй задачи.
# - Шаг 5. Подготовка данных: подготовим признаки так же, как и в первой задаче: выполним подготовку в пайплайне, дополнив пайплайн предобработки. При кодировании учитем особенности признаков и моделей и используем как минимум два кодировщика.
# - Шаг 6. Обучение модел: обучим как минимум три модели. Как минимум для двух из них подберем гиперпараметры. Проверим качество лучшей модели. Метрика оценки качества в этой задаче — ROC-AUC. Критерий успеха: ROC-AUC ≥0.91 на тестовой выборке. Важно: отбор признаков часто помогает улучшить метрику.
# - Шаг 7. Выводы: сделаем промежуточные выводы о том, какая модель справилась лучше и почему.
#
# **Общий вывод**
#
# - опишим задачу;
# - опишим все этапы работы;
# - добавим выводы и дополнительные предложения для бизнеса.

# %% [markdown]
# # Описание данных

# %% [markdown]
# **Задача 1: предсказание уровня удовлетворённости сотрудника**
#
# Тренировочная выборка: `train_job_satisfaction_rate.csv`
#
# Входные признаки тестовой выборки: `test_features.csv`
#
# Целевой признак тестовой выборки: `test_target_job_satisfaction_rate.csv`
#
# - `id` — уникальный идентификатор сотрудника;
# - `dept` — отдел, в котором работает сотрудник;
# - `level` — уровень занимаемой должности;
# - `workload` — уровень загруженности сотрудника;
# - `employment_years` — длительность работы в компании (в годах);
# - `last_year_promo` — показывает, было ли повышение за последний год;
# - `last_year_violations` — показывает, нарушал ли сотрудник трудовой договор за последний год;
# - `supervisor_evaluation` — оценка качества работы сотрудника, которую дал руководитель;
# - `salary` — ежемесячная зарплата сотрудника;
# - `job_satisfaction_rate` — уровень удовлетворённости сотрудника работой в компании, целевой признак.
#
# **Задача 2: предсказание увольнения сотрудника из компании**
#
# Тренировочная выборка: `train_quit.csv`
#
# Входные признаки тестовой выборки те же, что и в прошлой задаче: `test_features.csv`
#
# Целевой признак тестовой выборки: `test_target_quit.csv`

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Вижу твое добавленное описание и план проекта. Молодец! Это поможет тебе расставлять акценты в выводах

# %% [markdown]
# # Загрузка библиотек

# %%
# !pip install phik -q
# !pip install -U scikit-learn -q
# !pip install shap -q

# %%
# для работы с датасетами:
import pandas as pd

# математика:
import numpy as np

# для работы с графиками:
import matplotlib
from matplotlib import pyplot as plt
from matplotlib import rcParams, rcParamsDefault
import seaborn as sns
import plotly.express as px

# для расчета коэффициентов взаимосвязи
import phik

# для разделения выборок:
from sklearn.model_selection import train_test_split

# загружаем инструмент для автоподбора гиперпараметров
from sklearn.model_selection import GridSearchCV

# для подготовки данных:
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, LabelEncoder, PolynomialFeatures
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.inspection import permutation_importance
from sklearn.datasets import make_classification
import shap

# класс для работы с пропусками:
from sklearn.impute import SimpleImputer

# нужные модели:
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.svm import SVC

# импортируем класс RandomizedSearchCV
from sklearn.model_selection import RandomizedSearchCV

# загружаем класс pipeline:
from sklearn.pipeline import Pipeline

# загружаем функции для работы с метриками
from sklearn.metrics import (
    roc_auc_score, f1_score, 
    mean_squared_error, 
    r2_score, mean_absolute_error, 
    accuracy_score, confusion_matrix, 
    recall_score, precision_score, 
    precision_recall_curve,
    make_scorer
)

# для статистики:
from scipy import stats as st
from scipy.stats import binom, poisson, norm

# Убираем ненужные пердупреждения:
import warnings
warnings.filterwarnings('ignore')

# %%
# отображение всех колонок при выводе на печать
pd.set_option('display.max_columns', None)

# %%
# для настройки среды визуализации
rcParams['figure.figsize'] = 10, 6
# %config InlineBackend.figure_format = 'svg'
# дополнительно для графиков
factor = .8
default_dpi = rcParamsDefault['figure.dpi']
rcParams['figure.dpi'] = default_dpi * factor

# %%
# зафиксируем константы:
RANDOM_STATE = 42
TEST_SIZE = 0.25

# %% [markdown]
# ## Задача 1: предсказание уровня удовлетворённости сотрудника

# %% [markdown]
# ### Шаг 1. Загрузка данных

# %% [markdown]
# <a id='label_of_your_choice'></a>

# %%
try:
    train_job_satisfaction_rate = pd.read_csv('/datasets/train_job_satisfaction_rate.csv') 
    test_features = pd.read_csv('/datasets/test_features.csv') 
    test_target_job_satisfaction_rate = pd.read_csv('/datasets/test_target_job_satisfaction_rate.csv')
    train_quit = pd.read_csv('/datasets/train_quit.csv')
    test_target_quit = pd.read_csv('/datasets/test_target_quit.csv')
except:
    train_job_satisfaction_rate = pd.read_csv('https://code.s3.yandex.net/datasets/train_job_satisfaction_rate.csv') 
    test_features = pd.read_csv('https://code.s3.yandex.net/datasets/test_features.csv') 
    test_target_job_satisfaction_rate = pd.read_csv('https://code.s3.yandex.net/datasets/test_target_job_satisfaction_rate.csv')
    train_quit = pd.read_csv('https://code.s3.yandex.net/datasets/train_quit.csv')
    test_target_quit = pd.read_csv('https://code.s3.yandex.net/datasets/test_target_quit.csv')

# %%
# Для предварительного изучения данных, напишем функцию:
def df_info(df, size_x, size_y):
    df.info()
    print('*'*120)
    display(df.describe())
    print('*'*120)
    print('Количество явных дубликатов:', df.duplicated().sum())
    print('*'*120)
    df.hist(figsize=(size_x, size_y))
    display(df.head())

# %%
df_info(train_job_satisfaction_rate, 12, 15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   3994 non-null   object
#  2   level                  3996 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 312.6+ KB
# ************************************************************************************************************************
# ...

# %%
df_info(test_features, 12, 12)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB
# ************************************************************************************************************************
#                   id  employment_years  supervisor_evaluation        salary
# ...

# %%
df_info(test_target_job_satisfaction_rate, 12, 6)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB
# ************************************************************************************************************************
#                   id  job_satisfaction_rate
# count    2000.000000             2000.00000
# mean   552765.213500                0.54878
# std    253851.326129                0.22011
# min    100298.000000                0.03000
# 25%    339052.000000                0.38000
# 50%    550793.000000                0.58000
# 75%    765763.750000                0.72000
# max    999029.000000                1.00000
# ...

# %%
df_info(train_quit, 12, 8)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 312.6+ KB
# ************************************************************************************************************************
#                   id  employment_years  supervisor_evaluation        salary
# ...

# %%
df_info(test_target_quit, 6, 6)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2000 non-null   int64
#  1   quit    2000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB
# ************************************************************************************************************************
#                   id
# count    2000.000000
# mean   552765.213500
# std    253851.326129
# min    100298.000000
# 25%    339052.000000
# 50%    550793.000000
# 75%    765763.750000
# max    999029.000000
# ************************************************************************************************************************
# Количество явных дубликатов: 0
# ************************************************************************************************************************
#        id quit
# 0  999029  yes
# 1  372846   no
# 2  726767   no
# ...

# %% [markdown]
# ####  Вывод по итогам загрузки данных
#
# - Датафрейм `train_job_satisfaction_rate.csv`
#     - датафрейм содержит 10 столбцов и 4000 строк.
#     - Нарушений стиля в названиях столбцов не наблюдается.
#     - Имеются пропуски в столбцах `dept` - 6 пропусков, в `level` - 4. Заполнять их будем в пайплайне.
#     - Явных дубликатов нет. Могут присутствовать неявные дубликаты в категорийных столбцах. Рассмотрим их в шаге 2.
#     - Тип данных, на первый взгляд, соответствует наполнению, изменение не требуется.
#     - Явных выбросов и аномалий не наблюдается.
# - Датафрейм `test_features.csv`
#     - датафрейм содержит 9 столбцов и 2000 строк.
#     - Нарушений стиля в названиях столбцов не наблюдается.
#     - Имеются пропуски в столбцах `dept` - 2 пропуска, в `level` - 1. Заполнять их будем в пайплайне.
#     - Явных дубликатов нет. Могут присутствовать неявные дубликаты в категорийных столбцах. Рассмотрим их в шаге 2.
#     - Тип данных, на первый взгляд, соответствует наполнению, изменение не требуется.
#     - Явных выбросов и аномалий не наблюдается.
# - Датафрейм `test_target_job_satisfaction_rate.csv`
#     - датафрейм содержит 2 столбца и 2000 строк.
#     - Нарушений стиля в названиях столбцов не наблюдается.
#     - Пропуски в столбцах отсутствуют.
#     - Явных дубликатов нет.
#     - Тип данных соответствует наполнению, на первый взгляд, изменение не требуется.
#     - Явных выбросов и аномалий не наблюдается.
# - Датафрейм `train_quit.csv`
#     - датафрейм содержит 10 столбцов и 4000 строк.
#     - Нарушений стиля в названиях столбцов не наблюдается.
#     - Пропуски в столбцах отсутствуют.
#     - Явных дубликатов нет. Могут присутствовать неявные дубликаты в категорийных столбцах. Рассмотрим их в шаге 2.
#     - Тип данных соответствует наполнению, на первый взгляд, изменение не требуется.
#     - Явных выбросов и аномалий не наблюдается.
# - Датафрейм `test_target_quit.csv`
#     - датафрейм содержит 2 столбца и 2000 строк.
#     - Нарушений стиля в названиях столбцов не наблюдается.
#     - Пропуски в столбцах отсутствуют.
#     - Явных дубликатов нет. Могут присутствовать неявные дубликаты в категорийных столбцах. Рассмотрим их в шаге 2.
#     - Тип данных соответствует наполнению, на первый взгляд, изменение не требуется.
#     - Явных выбросов и аномалий не наблюдается.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# С данными познакомились, проведен первичный аналитический осмотр!) Полученная информация поможет нам в дальнейшем с предобработкой данных

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# <a id='label_of_your_choice_2'></a>

# %% [markdown]
# Так как обработку пропусков, согласно условию, решили провести в пайплане, проверим категориальные столбцы датафреймов на скрытые дубликаты, описки, орфографические ошибки.

# %%
# для удобства, напишем функцию:
def double_search(df, column):
    display(df[column].value_counts().sort_index())
    print('*'*120)
    display(df[column].unique())

# %%
double_search(train_job_satisfaction_rate, 'dept')
# Out:
# hr             456
# marketing      550
# purchasing     610
# sales         1512
# technology     866
# Name: dept, dtype: int64
# ************************************************************************************************************************
# array(['sales', 'hr', 'technology', 'purchasing', 'marketing', nan],
#       dtype=object)

# %%
double_search(train_job_satisfaction_rate, 'level')
# Out:
# junior    1894
# middle    1744
# sinior     358
# Name: level, dtype: int64
# ************************************************************************************************************************
# array(['junior', 'middle', 'sinior', nan], dtype=object)

# %%
double_search(train_job_satisfaction_rate, 'workload')
# Out:
# high       734
# low       1200
# medium    2066
# Name: workload, dtype: int64
# ************************************************************************************************************************
# array(['medium', 'high', 'low'], dtype=object)

# %%
double_search(train_job_satisfaction_rate, 'last_year_promo')
# Out:
# no     3880
# yes     120
# Name: last_year_promo, dtype: int64
# ************************************************************************************************************************
# array(['no', 'yes'], dtype=object)

# %%
double_search(train_job_satisfaction_rate, 'last_year_violations')
# Out:
# no     3441
# yes     559
# Name: last_year_violations, dtype: int64
# ************************************************************************************************************************
# array(['no', 'yes'], dtype=object)

# %%
double_search(test_features, 'dept')
# Out:
#                 1
# hr            227
# marketing     279
# purchasing    273
# sales         763
# technology    455
# Name: dept, dtype: int64
# ************************************************************************************************************************
# array(['marketing', 'hr', 'sales', 'purchasing', 'technology', nan, ' '],
#       dtype=object)

# %%
double_search(test_features, 'level')
# Out:
# junior    974
# middle    854
# sinior    171
# Name: level, dtype: int64
# ************************************************************************************************************************
# array(['junior', 'middle', 'sinior', nan], dtype=object)

# %%
double_search(test_features, 'workload')
# Out:
#              1
# high       363
# low        593
# medium    1043
# Name: workload, dtype: int64
# ************************************************************************************************************************
# array(['medium', 'low', 'high', ' '], dtype=object)

# %%
double_search(test_features, 'last_year_promo')
# Out:
# no     1937
# yes      63
# Name: last_year_promo, dtype: int64
# ************************************************************************************************************************
# array(['no', 'yes'], dtype=object)

# %%
double_search(test_features, 'last_year_violations')
# Out:
# no     1738
# yes     262
# Name: last_year_violations, dtype: int64
# ************************************************************************************************************************
# array(['no', 'yes'], dtype=object)

# %%
double_search(train_quit, 'dept')
# Out:
# hr             464
# marketing      582
# purchasing     588
# sales         1438
# technology     928
# Name: dept, dtype: int64
# ************************************************************************************************************************
# array(['sales', 'purchasing', 'marketing', 'technology', 'hr'],
#       dtype=object)

# %%
double_search(train_quit, 'level')
# Out:
# junior    1949
# middle    1694
# sinior     357
# Name: level, dtype: int64
# ************************************************************************************************************************
# array(['middle', 'junior', 'sinior'], dtype=object)

# %%
double_search(train_quit, 'workload')
# Out:
# high       674
# low       1208
# medium    2118
# Name: workload, dtype: int64
# ************************************************************************************************************************
# array(['high', 'medium', 'low'], dtype=object)

# %%
double_search(train_quit, 'last_year_promo')
# Out:
# no     3887
# yes     113
# Name: last_year_promo, dtype: int64
# ************************************************************************************************************************
# array(['no', 'yes'], dtype=object)

# %%
double_search(train_quit, 'last_year_violations')
# Out:
# no     3455
# yes     545
# Name: last_year_violations, dtype: int64
# ************************************************************************************************************************
# array(['no', 'yes'], dtype=object)

# %%
double_search(train_quit, 'quit')
# Out:
# no     2872
# yes    1128
# Name: quit, dtype: int64
# ************************************************************************************************************************
# array(['no', 'yes'], dtype=object)

# %%
double_search(test_target_quit, 'quit')
# Out:
# no     1436
# yes     564
# Name: quit, dtype: int64
# ************************************************************************************************************************
# array(['yes', 'no'], dtype=object)

# %% [markdown]
# Заменим `sinior` на `senior`  в столбцах `level` датафреймов `train_job_satisfaction_rate`, `test_features` и `train_quit`. На качество модели это не повлияет, но глаз порадуется:

# %%
train_job_satisfaction_rate['level'] = train_job_satisfaction_rate['level'].replace(['sinior'], 'senior', regex=True)
test_features['level'] = test_features['level'].replace(['sinior'], 'senior', regex=True)
train_quit['level'] = train_quit['level'].replace(['sinior'], 'senior', regex=True)

# %%
double_search(train_job_satisfaction_rate, 'level')
# Out:
# junior    1894
# middle    1744
# senior     358
# Name: level, dtype: int64
# ************************************************************************************************************************
# array(['junior', 'middle', 'senior', nan], dtype=object)

# %%
double_search(test_features, 'level')
# Out:
# junior    974
# middle    854
# senior    171
# Name: level, dtype: int64
# ************************************************************************************************************************
# array(['junior', 'middle', 'senior', nan], dtype=object)

# %%
double_search(train_quit, 'level')
# Out:
# junior    1949
# middle    1694
# senior     357
# Name: level, dtype: int64
# ************************************************************************************************************************
# array(['middle', 'junior', 'senior'], dtype=object)

# %% [markdown]
# #### Вывод по итогам предобработки данных

# %% [markdown]
# - Проверка на неявные дубликаты показала их отсутствие.
# - Исправили орфографическую ошибку - заменили `sinior` на `senior`  в столбцах `level` датафреймов `train_job_satisfaction_rate`, `test_features` и `train_quit`.
# - Обнаружили "пропуски" в виде пробелов в столбцах `dept` и `workload` датафрейма `test_features` - обработаем их в пайпланее вместе с nan.
#
# Можно приступать к исследовательскому анализу.

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Предобработку данных провели) Переходим к исследовательскому анализу данных

# %% [markdown]
# ### Шаг 3. Исследовательский анализ данных

# %% [markdown]
# <a id='label_of_your_choice_3'></a>

# %% [markdown]
# Для удобства проведения анализа создадим функции для описания количественных и категориальных признаков:

# %%
def describe_numeric_column(target_df, target_column):
    display(target_df[target_column].head(10))
    print('*'*50)
    display(target_df[target_column].describe())
    plt.title(f'Бокс плот {target_column}')
    target_df.boxplot(column=target_column, figsize=(3,5)); 
    plt.show()
    plt.title(f'Гистограмма {target_column}')
    plt.xlabel(target_column)
    plt.ylabel('Количество')
    target_df[target_column].hist(figsize=(12,3), bins=50);

# %%
def describe_category_column(target_df, target_column):
    print(target_df[target_column].value_counts().sort_index())
    describe_category_pie = target_df.pivot_table(index = target_column, 
                                                       values = 'id', 
                                                       aggfunc = 'count').sort_values('id',
                                                                                    ascending = False).reset_index()
    sns.countplot(data=target_df, x=target_column);
    plt.title(f'Распределение данных по признаку "{target_column}":')
    plt.ylabel('Количество')
    plt.show()

# %% [markdown]
# #### Исследовательский анализ данных количественных признаков

# %%
describe_numeric_column(train_job_satisfaction_rate, 'employment_years')
# Out:
# 0    2
# 1    2
# 2    1
# 3    4
# 4    1
# 5    7
# 6    9
# 7    9
# 8    1
# 9    6
# Name: employment_years, dtype: int64
# **************************************************
# count    4000.000000
# mean        3.718500
# std         2.542513
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         6.000000
# max        10.000000
# Name: employment_years, dtype: float64

# %% [markdown]
# В признаке "employment_years" датафрейма "train_job_satisfaction_rate" выбросов и аномальных значений не наблюдается. Распределение напоминает распределение Пуассона

# %%
describe_numeric_column(train_job_satisfaction_rate, 'supervisor_evaluation')
# Out:
# 0    1
# 1    5
# 2    2
# 3    2
# 4    3
# 5    4
# 6    3
# 7    3
# 8    2
# 9    3
# Name: supervisor_evaluation, dtype: int64
# **************************************************
# count    4000.000000
# mean        3.476500
# std         1.008812
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: supervisor_evaluation, dtype: float64

# %% [markdown]
# В признаке "supervisor_evaluation" датафрейма "train_job_satisfaction_rate" выбросов и аномальных значений не наблюдается. Есть значения за пределами "усов" боксплота, однако аномалиями или выбросами это назвать нельзя. Оставляем. Распределение напоминает распределение Пуассона

# %%
describe_numeric_column(train_job_satisfaction_rate, 'salary')
# Out:
# 0    24000
# 1    38400
# 2    12000
# 3    18000
# 4    22800
# 5    30000
# 6    56400
# 7    52800
# 8    13200
# 9    54000
# Name: salary, dtype: int64
# **************************************************
# count     4000.000000
# mean     33926.700000
# std      14900.703838
# min      12000.000000
# 25%      22800.000000
# 50%      30000.000000
# 75%      43200.000000
# max      98400.000000
# Name: salary, dtype: float64

# %% [markdown]
# В признаке "salary" датафрейма "train_job_satisfaction_rate" выбросов и аномальных значений не наблюдается. Есть значения за пределами "усов" боксплота, однако аномалиями или выбросами это назвать нельзя. Оставляем. Распределение напоминает распределение Пуассона

# %%
describe_numeric_column(train_job_satisfaction_rate, 'job_satisfaction_rate')
# Out:
# 0    0.58
# 1    0.76
# 2    0.11
# 3    0.37
# 4    0.20
# 5    0.78
# 6    0.56
# 7    0.44
# 8    0.14
# 9    0.47
# Name: job_satisfaction_rate, dtype: float64
# **************************************************
# count    4000.000000
# mean        0.533995
# std         0.225327
# min         0.030000
# 25%         0.360000
# 50%         0.560000
# 75%         0.710000
# max         1.000000
# Name: job_satisfaction_rate, dtype: float64

# %% [markdown]
# В признаке "job_satisfaction_rate" датафрейма "train_job_satisfaction_rate" выбросов и аномальных значений не наблюдается. Распределение напоминает распределение Пуассона

# %%
describe_numeric_column(test_features, 'employment_years')
# Out:
# 0    2
# 1    1
# 2    5
# 3    6
# 4    5
# 5    6
# 6    3
# 7    9
# 8    3
# 9    1
# Name: employment_years, dtype: int64
# **************************************************
# count    2000.000000
# mean        3.666500
# std         2.537222
# min         1.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        10.000000
# Name: employment_years, dtype: float64

# %% [markdown]
# В признаке "employment_years" датафрейма "test_features" выбросов и аномальных значений не наблюдается. Распределение напоминает распределение Пуассона

# %%
describe_numeric_column(test_features, 'supervisor_evaluation')
# Out:
# 0    5
# 1    4
# 2    4
# 3    4
# 4    5
# 5    3
# 6    3
# 7    4
# 8    4
# 9    3
# Name: supervisor_evaluation, dtype: int64
# **************************************************
# count    2000.000000
# mean        3.526500
# std         0.996892
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: supervisor_evaluation, dtype: float64

# %% [markdown]
# В признаке "supervisor_evaluation" датафрейма "test_features" выбросов и аномальных значений не наблюдается. Есть значения за пределами "усов" боксплота, однако аномалиями или выбросами это назвать нельзя. Оставляем. Распределение напоминает распределение Пуассона

# %%
describe_numeric_column(test_features, 'salary')
# Out:
# 0    28800
# 1    30000
# 2    19200
# 3    19200
# 4    40800
# 5    42000
# 6    26400
# 7    49200
# 8    62400
# 9    26400
# Name: salary, dtype: int64
# **************************************************
# count     2000.000000
# mean     34066.800000
# std      15398.436729
# min      12000.000000
# 25%      22800.000000
# 50%      30000.000000
# 75%      43200.000000
# max      96000.000000
# Name: salary, dtype: float64

# %% [markdown]
# В признаке "salary" датафрейма "test_features" выбросов и аномальных значений не наблюдается. Есть значения за пределами "усов" боксплота, однако аномалиями или выбросами это назвать нельзя. Оставляем. Распределение напоминает распределение Пуассона

# %%
describe_numeric_column(test_target_job_satisfaction_rate, 'job_satisfaction_rate')
# Out:
# 0    0.74
# 1    0.75
# 2    0.60
# 3    0.72
# 4    0.08
# 5    0.76
# 6    0.64
# 7    0.38
# 8    0.14
# 9    0.59
# Name: job_satisfaction_rate, dtype: float64
# **************************************************
# count    2000.00000
# mean        0.54878
# std         0.22011
# min         0.03000
# 25%         0.38000
# 50%         0.58000
# 75%         0.72000
# max         1.00000
# Name: job_satisfaction_rate, dtype: float64

# %% [markdown]
# В признаке "job_satisfaction_rate" датафрейма "test_target_job_satisfaction_rate" выбросов и аномальных значений не наблюдается. Распределение напоминает распределение Пуассона

# %% [markdown]
# #### Исследовательский анализ данных категориальных признаков

# %%
describe_category_column(train_job_satisfaction_rate, 'dept')
# Out:
# hr             456
# marketing      550
# purchasing     610
# sales         1512
# technology     866
# Name: dept, dtype: int64

# %% [markdown]
# В признаке "dept" датафрейма "train_job_satisfaction_rate" наблюдается явный дисбаланс классов. В частности выделяется "sales". Наверняка понадобится семплирование. Данный признак лучше кодировать OneHotEncoder

# %%
describe_category_column(train_job_satisfaction_rate, 'level')
# Out:
# junior    1894
# middle    1744
# senior     358
# Name: level, dtype: int64

# %% [markdown]
# В признаке "level" датафрейма "train_job_satisfaction_rate" наблюдается явный дисбаланс классов. Уровня "senior" заметно меньше остальных. Наверняка понадобится семплирование. Данный признак лучше кодировать OrdinalEncoder.

# %%
describe_category_column(train_job_satisfaction_rate, 'workload')
# Out:
# high       734
# low       1200
# medium    2066
# Name: workload, dtype: int64

# %% [markdown]
# В признаке "workload" датафрейма "train_job_satisfaction_rate" наблюдается явный дисбаланс классов. Уровня "medium" заметно больше остальных. Наверняка понадобится семплирование. Данный признак лучше кодировать OrdinalEncoder.

# %%
describe_category_column(train_job_satisfaction_rate, 'last_year_promo')
# Out:
# no     3880
# yes     120
# Name: last_year_promo, dtype: int64

# %% [markdown]
# В признаке "last_year_promo" датафрейма "train_job_satisfaction_rate" наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Наверняка понадобится семплирование. Данный признак лучше кодировать OneHotEncoder.

# %%
describe_category_column(train_job_satisfaction_rate, 'last_year_violations')
# Out:
# no     3441
# yes     559
# Name: last_year_violations, dtype: int64

# %% [markdown]
# В признаке "last_year_violations" датафрейма "train_job_satisfaction_rate" наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Наверняка понадобится семплирование. Данный признак лучше кодировать OneHotEncoder.

# %%
describe_category_column(test_features, 'dept')
# Out:
#                 1
# hr            227
# marketing     279
# purchasing    273
# sales         763
# technology    455
# Name: dept, dtype: int64

# %% [markdown]
# В признаке "dept" датафрейма "test_features" наблюдается явный дисбаланс классов. В частности выделяется "sales". Наверняка понадобится семплирование. Данный признак лучше кодировать OneHotEncoder

# %%
describe_category_column(test_features, 'level')
# Out:
# junior    974
# middle    854
# senior    171
# Name: level, dtype: int64

# %% [markdown]
# В признаке "level" датафрейма "test_features" наблюдается явный дисбаланс классов. Уровня "senior" заметно меньше остальных. Наверняка понадобится семплирование. Данный признак лучше кодировать OrdinalEncoder.

# %%
describe_category_column(test_features, 'workload')
# Out:
#              1
# high       363
# low        593
# medium    1043
# Name: workload, dtype: int64

# %% [markdown]
# В признаке "workload" датафрейма "test_features" наблюдается явный дисбаланс классов. Уровня "medium" заметно больше остальных. Наверняка понадобится семплирование. Данный признак лучше кодировать OrdinalEncoder.

# %%
describe_category_column(test_features, 'last_year_promo')
# Out:
# no     1937
# yes      63
# Name: last_year_promo, dtype: int64

# %% [markdown]
# В признаке "last_year_promo" датафрейма "test_features" наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Наверняка понадобится семплирование. Данный признак лучше кодировать OneHotEncoder.

# %%
describe_category_column(test_features, 'last_year_violations')
# Out:
# no     1738
# yes     262
# Name: last_year_violations, dtype: int64

# %% [markdown]
# В признаке "last_year_violations" датафрейма "test_features" наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Наверняка понадобится семплирование. Данный признак лучше кодировать OneHotEncoder.

# %% [markdown]
# #### Матрицы корреляции признаков в тренировочной и тестовой выборках

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(train_job_satisfaction_rate.drop('id', axis=1)
            .phik_matrix(interval_cols = ['employment_years', 
                                          'supervisor_evaluation', 
                                          'salary', 
                                          'job_satisfaction_rate']), annot=True, cmap='coolwarm');
plt.title('Phi_K Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(test_features.drop('id', axis=1)
            .phik_matrix(interval_cols = ['employment_years', 
                                          'supervisor_evaluation', 
                                          'salary']), annot=True, cmap='coolwarm');
plt.title('Phi_K Correlation Matrix')
plt.show()

# %% [markdown]
# - Судя по тепловой карте, самая сильная прямая связь с целевым признаком `job_satisfaction_rate` наблюдается у входных признаков `supervisor_evaluation` и `last_year_violations`.
# - Существует также связь между входными признаками `salary` и `workload`, `salary` и `level`, `level` и `employment_years`. Однако при таком значении индекса, это не мультиколлинеарность
# - Очень высоких корреляций (0.9 +) не видно, скорее всего мультиколлинеарности нет.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отлично, что при использовании phik настроен параметр interval_cols)

# %% [markdown]
# #### Вывод по итогам исследовательского анализа
#
# **Количественные признаки**
#
# - В признаке "employment_years" датафрейма "train_job_satisfaction_rate" выбросов и аномальных значений не наблюдается. Распределение напоминает распределение Пуассона. Понадобится масштабирование.
# - В признаке "supervisor_evaluation" датафрейма "train_job_satisfaction_rate" выбросов и аномальных значений не наблюдается. Есть значения за пределами "усов" боксплота, однако аномалиями или выбросами это назвать нельзя. Оставляем. Распределение напоминает распределение Пуассона. Понадобится масштабирование.
# - В признаке "salary" датафрейма "train_job_satisfaction_rate" выбросов и аномальных значений не наблюдается. Есть значения за пределами "усов" боксплота, однако аномалиями или выбросами это назвать нельзя. Оставляем. Распределение напоминает распределение Пуассона. Понадобится масштабирование.
# - В признаке "job_satisfaction_rate" датафрейма "train_job_satisfaction_rate" выбросов и аномальных значений не наблюдается. Распределение напоминает распределение Пуассона
# - В признаке "employment_years" датафрейма "test_features" выбросов и аномальных значений не наблюдается. Распределение напоминает распределение Пуассона. Понадобится масштабирование.
# - В признаке "supervisor_evaluation" датафрейма "test_features" выбросов и аномальных значений не наблюдается. Есть значения за пределами "усов" боксплота, однако аномалиями или выбросами это назвать нельзя. Оставляем. Распределение напоминает распределение Пуассона. Понадобится масштабирование.
# - В признаке "salary" датафрейма "test_features" выбросов и аномальных значений не наблюдается. Есть значения за пределами "усов" боксплота, однако аномалиями или выбросами это назвать нельзя. Оставляем. Распределение напоминает распределение Пуассона. Понадобится масштабирование.
# - В признаке "job_satisfaction_rate" датафрейма "test_target_job_satisfaction_rate" выбросов и аномальных значений не наблюдается. Распределение напоминает распределение Пуассона
#
# **Категориальные признаки**
#
# - В признаке "dept" датафрейма "train_job_satisfaction_rate" наблюдается явный дисбаланс классов. В частности выделяется "sales". Возможно понадобится семплирование. Данный признак лучше кодировать OneHotEncoder
# - В признаке "level" датафрейма "train_job_satisfaction_rate" наблюдается явный дисбаланс классов. Уровня "senior" заметно меньше остальных. Возможно понадобится семплирование. Данный признак лучше кодировать OrdinalEncoder.
# - В признаке "workload" датафрейма "train_job_satisfaction_rate" наблюдается явный дисбаланс классов. Уровня "medium" заметно больше остальных. Возможно понадобится семплирование. Данный признак лучше кодировать OrdinalEncoder.
# - В признаке "last_year_promo" датафрейма "train_job_satisfaction_rate" наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Возможно понадобится семплирование. Данный признак лучше кодировать OneHotEncoder.
# - В признаке "last_year_violations" датафрейма "train_job_satisfaction_rate" наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Возможно понадобится семплирование. Данный признак лучше кодировать OneHotEncoder.
# - В признаке "dept" датафрейма "test_features" наблюдается явный дисбаланс классов. В частности выделяется "sales". Возможно понадобится семплирование. Данный признак лучше кодировать OneHotEncoder
# - В признаке "level" датафрейма "test_features" наблюдается явный дисбаланс классов. Уровня "senior" заметно меньше остальных. Возможно понадобится семплирование. Данный признак лучше кодировать OrdinalEncoder.
# - В признаке "workload" датафрейма "test_features" наблюдается явный дисбаланс классов. Уровня "medium" заметно больше остальных. Возможно понадобится семплирование. Данный признак лучше кодировать OrdinalEncoder.
# - В признаке "last_year_promo" датафрейма "test_features" наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Возможно понадобится семплирование. Данный признак лучше кодировать OneHotEncoder.
# - В признаке "last_year_violations" датафрейма "test_features" наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Возможно понадобится семплирование. Данный признак лучше кодировать OneHotEncoder.
#
# **Матрицы корреляции**
#
# - Судя по тепловой карте, самая сильная прямая связь с целевым признаком `job_satisfaction_rate` наблюдается у входных признаков `supervisor_evaluation` и `last_year_violations`.
# - Существует также связь между входными признаками `salary` и `workload`, `salary` и `level`, `level` и `employment_years`. Однако при таком значении индекса, это не мультиколлинеарность
# - Очень высоких корреляций (0.9 +) не видно, скорее всего мультиколлинеарности нет.
#
#
# - На графиках снова увидели "пропущенные" значения в виде пробелов. Заполним их в следующем шаге

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Верно!👍:\
# </b> Мне интересно было изучить проведенный исследовательский анализ данных, твои графики, осмысленный и красочный графический анализ. Найдены очень интересные закономерности)

# %% [markdown]
# ### Шаг 4. Подготовка данных

# %% [markdown]
# Для начала столбец `id` переведем в индекс для удобства и отсортируем по индексу:

# %%
train_job_satisfaction_rate = train_job_satisfaction_rate.set_index('id').sort_index(ascending=True)
test_features = test_features.set_index('id').sort_index(ascending=True)
test_target_job_satisfaction_rate = test_target_job_satisfaction_rate.set_index('id').sort_index(ascending=True)
display(train_job_satisfaction_rate.head())
print('*'*120)
display(test_features.head())
print('*'*120)
test_target_job_satisfaction_rate.head()
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 100954  purchasing  junior      low                 1              no
# 101057       sales  junior      low                 1              no
# 101074       sales  junior   medium                 2              no
# 101081       sales  middle      low                 2              no
# 101129  technology  junior   medium                 1              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# 100954                   no                      4   15600
# 101057                  yes                      4   19200
# 101074                   no                      2   20400
# 101081                   no                      4   28800
# 101129                   no                      4   34800
#
#         job_satisfaction_rate
# id
# 100954                   0.60
# 101057                   0.45
# 101074                   0.36
# 101081                   0.66
# ...

# %% [markdown]
# После перевода столбца `id` в индекс, у нас могла появиться новые дубликаты. Для тетовой выборки это не важно, а вот дубликаты в тренировочной выборке могут навредить будущей модели. Проверим наличие дубликатов в тренировочной выборке:

# %%
train_job_satisfaction_rate.duplicated().sum()
# Out:
# 245

# %% [markdown]
# Получается, что из 4000 строк у нас 245 являются явными дубликатами. Так как это составляет примерно 6% от общего количества строк, можно удалить эти данные, чтобы не навредить будущей модели:

# %%
train_job_satisfaction_rate = train_job_satisfaction_rate.drop_duplicates()
train_job_satisfaction_rate.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Перечислим особенности данных:
#
# 1. Целевой признак — `job_satisfaction_rate`.
# 2. Три признака: `dept`, `last_year_promo`, `last_year_violations` — нужно кодировать с помощью OneHotEncoder.
# 3. Два признака: `level`, `workload` — нужно кодировать с помощью OrdinalEncoder.
# 4. Количественные признаки `employment_years`, `supervisor_evaluation`, `salary` нужно масштабировать.
# 5. Необходима обработка пропусков.

# %%
# проведем разметку целевого и входных признаков на тренировочной и тестовой выборках:
X_train = train_job_satisfaction_rate.drop(['job_satisfaction_rate'], axis=1)
y_train = train_job_satisfaction_rate['job_satisfaction_rate']

X_test = test_features
y_test = test_target_job_satisfaction_rate['job_satisfaction_rate']

# создаём списки с названиями признаков
ohe_columns = ['dept', 'last_year_promo', 'last_year_violations']
ord_columns = ['level', 'workload']
num_columns = ['employment_years', 'supervisor_evaluation', 'salary']

# создаём пайплайн для подготовки признаков из списка ohe_columns: заполнение пропусков и OHE-кодирование
# SimpleImputer + OHE
ohe_pipe = Pipeline(
    [
        (
            'simpleImputer_ohe_nan_1', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'simpleImputer_ohe_nan_spase', 
            SimpleImputer(missing_values=" ", strategy='constant', fill_value=np.nan)
        ),
        (
            'simpleImputer_ohe_nan_2', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ohe', 
            OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False)
        )
    ]
)

# cоздаём пайплайн для подготовки признаков из списка ord_columns: заполнение пропусков и Ordinal-кодирование
# SimpleImputer + OE
ord_pipe = Pipeline(
    [
        (
            'simpleImputer_before_ord_nan_1', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'simpleImputer_before_ord_space', 
            SimpleImputer(missing_values=" ", strategy='constant', fill_value=np.nan)
        ),
        (
            'simpleImputer_before_ord_nan_2', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ord',  
            OrdinalEncoder(
                categories=[
                    ['junior', 'middle', 'senior'],
                    ['high', 'medium', 'low']
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
        (
            'simpleImputer_after_ord', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
)

# создаём общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_columns),
        ('ord', ord_pipe, ord_columns),
        ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %% [markdown]
# #### Вывод по итогам предобрботки данных
#
# Для подготовки данных мы:
# - перевели столбец "id" в индекс для удобства и отсортировали датафреймы по индексу с целью упорядочить данные в тестовых выборках (входные и целевой признаки);
# - убрали возникшие дубликаты из тренировочной выборки, чтобы избавиться от негативного воздействия их на модель;
# - провели разметку целевого и входных признаков на тренировочной и тестовой выборках;
# - обработали пропуски nan  и пробелы с помощью SimpleImputer;
# - создали пайплайн с использованием ColumnTransformer. Количественные и категориальные данные обработаны в пайплайне раздельно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
#
# Отлично, что использовано более одного энкодера, взятого из готовой реализации библиотеки sklearn)

# %% [markdown]
# ### Шаг 5. Обучение моделей

# %%
# создаем итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline(
    [
        ('preprocessor', data_preprocessor),
        ('models', DecisionTreeRegressor(random_state=RANDOM_STATE))
    ]
)

# создаем список моделей с перебором параметров:

param_grid = [
    # словарь для модели DecisionTreeRegressor()
    {
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 20),        
        'models__min_samples_split': range(2, 10),
#        'models__min_samples_leaf': range(2, 10),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели LinearRegression() 
    {
        'models': [LinearRegression()],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    }
]

# %%
# создадим функцию которая принимает на вход массивы NumPy или объекты Series в pandas и возвращает значение метрики SMAPE:
def smape(y_true, y_pred):
    return 100 / len(y_true) * np.sum(np.abs(y_true - y_pred) / ((np.abs(y_true) + np.abs(y_pred)) / 2))
smape_score = make_scorer(smape, greater_is_better=False)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Верно, что задаешь параметр `greater_is_better=False`. Дело в том, что разработчики пакета `sklearn` при создании функций `cross_val_score` и `GridSearchCV` утвердили соглашение: возвращаемые результаты вычислений данных функций должны соответствовать задаче максимизации (чем большее значение метрики получаем, тем лучше). При этом обратная задача минимизации может быть осуществлена через максимизацию метрики, домноженной на -1. Об этом можно чуть подробнее почитать в документации пакета, правда она на английском. Оставлю <a href = 'https://scikit-learn.org/stable/modules/model_evaluation.html'>ссылку</a>.

# %%
# %%time

grid_search = GridSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring=smape_score,
    n_jobs=-1
)
grid_search.fit(X_train, y_train)
# Out:
# CPU times: user 1min 14s, sys: 768 ms, total: 1min 14s
# Wall time: 1min 15s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ohe',
#                                                                          Pipeline(steps=[('simpleImputer_ohe_nan_1',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('simpleImputer_ohe_nan_spase',
#                                                                                           SimpleImputer(fill_value=nan,
#                                                                                                         missing_values=' ',
# ...

# %%
print('Лучшая модель и её параметры:\n\n', grid_search.best_estimator_)
print ('Метрика лучшей модели на кроссвалидационной выборке:', round((-1 * grid_search.best_score_), 2))
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe_nan_1',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('simpleImputer_ohe_nan_spase',
#                                                                    SimpleImputer(fill_value=nan,
#                                                                                  missing_values=' ',
#                                                                                  strategy='constant')),
#                                                                   ('simpleImputer_ohe_nan_2',
# ...

# %%
y_pred = grid_search.predict(X_test)
print(f'Метрика SMAP на тестовой выборке: {round(smape(y_test, y_pred), 2)}')
# Out:
# Метрика SMAP на тестовой выборке: 13.76

# %% [markdown]
# #### Вывод по итогам обучения модели
#
# В процессе обучения модели:
# - создали итоговый пайплайн: подготовка данных и модель;
# - создали пайплайн для поиска лучшей модели из: DecisionTreeRegressor(), LinearRegression()
# - создали функцию для определения новой метрики — SMAPE (англ. symmetric mean absolute percentage error, «симметричное среднее абсолютное процентное отклонение»)
# - По итогам, лучшей моделью определена модель DecisionTreeRegressor с гиперпараметрами max_depth=17, min_samples_split=7.
# - При этом ее метрика на тестовой выборке составила - 13.76.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Тестирование лучшей модели проведено правильно

# %% [markdown]
# ### Шаг 6. Оформление выводов

# %% [markdown]
# - В результате проведенных предобработки, исследовательских анализов, подготовки данных, создания пайплайна, была была построена  модель DecisionTreeRegressor с гиперпараметрами max_depth=17, min_samples_split=7.
# - Данная модель сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика. По результатам полученных прогнозных значений, заказчик сможет предсказывать отток сотрудников, что поможет, в конечном итоге оказать положительное влияние на бизнес, так как внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Приятно видеть общий вывод)

# %% [markdown]
# ## Задача 2: предсказание увольнения сотрудника из компании

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# В этой задаче по аналогичным заданиям и действиям в проекте -  аналогичные замечания (я их привел выше в первой части проекта), без исправления которых проект принят не будет.
#
# Новые неповторяющиеся замечания будут даны ниже отдельно

# %% [markdown]
# ### Шаг 1. Загрузка данных

# %% [markdown]
# Все данные мы уже загрузили [ТУТ](#label_of_your_choice), поэтому перейдем к следующему шагу

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# Все данные мы уже предобработали и сделали выводы по итогам предобработки [ТУТ](#label_of_your_choice_2), поэтому перейдем к следующему шагу

# %% [markdown]
# ### Шаг 3. Исследовательский анализ данных

# %% [markdown]
# Так как исследовательский анализ датафрейма `test_features.csv` мы уже провели [ТУТ](#label_of_your_choice_3), проведем его для неисследованных `train_quit.csv` и `test_target_quit.csv`, используя ранее написанные функции

# %% [markdown]
# #### Исследовательский анализ данных количественных признаков

# %%
describe_numeric_column(train_quit, 'employment_years')
# Out:
# 0    2
# 1    2
# 2    5
# 3    2
# 4    2
# 5    1
# 6    8
# 7    4
# 8    7
# 9    2
# Name: employment_years, dtype: int64
# **************************************************
# count    4000.000000
# mean        3.701500
# std         2.541852
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         6.000000
# max        10.000000
# Name: employment_years, dtype: float64

# %% [markdown]
# В признаке "employment_years" датафрейма "train_quit" выбросов и аномальных значений не наблюдается. Распределение напоминает распределение Пуассона. Понадобится масштабирование.

# %%
describe_numeric_column(train_quit, 'supervisor_evaluation')
# Out:
# 0    4
# 1    4
# 2    1
# 3    3
# 4    5
# 5    3
# 6    2
# 7    5
# 8    4
# 9    3
# Name: supervisor_evaluation, dtype: int64
# **************************************************
# count    4000.000000
# mean        3.474750
# std         1.004049
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: supervisor_evaluation, dtype: float64

# %% [markdown]
# В признаке "supervisor_evaluation" датафрейма "train_quit" выбросов и аномальных значений не наблюдается. Есть значения за пределами "усов" боксплота, однако аномалиями или выбросами это назвать нельзя. Оставляем. Распределение напоминает распределение Пуассона. Понадобится масштабирование.

# %%
describe_numeric_column(train_quit, 'salary')
# Out:
# 0    54000
# 1    27600
# 2    37200
# 3    24000
# 4    25200
# 5    18000
# 6    44400
# 7    19200
# 8    25200
# 9    45600
# Name: salary, dtype: int64
# **************************************************
# count     4000.000000
# mean     33805.800000
# std      15152.415163
# min      12000.000000
# 25%      22800.000000
# 50%      30000.000000
# 75%      43200.000000
# max      96000.000000
# Name: salary, dtype: float64

# %% [markdown]
# В признаке "salary" датафрейма "train_quit" выбросов и аномальных значений не наблюдается. Есть значения за пределами "усов" боксплота, однако аномалиями или выбросами это назвать нельзя. Оставляем. Распределение напоминает распределение Пуассона. Понадобится масштабирование.

# %% [markdown]
# #### Исследовательский анализ данных категориальных признаков

# %%
describe_category_column(train_quit, 'dept')
# Out:
# hr             464
# marketing      582
# purchasing     588
# sales         1438
# technology     928
# Name: dept, dtype: int64

# %% [markdown]
# В признаке "dept" датафрейма "train_quit" наблюдается явный дисбаланс классов. В частности выделяется "sales". Данный признак лучше кодировать OneHotEncoder

# %%
describe_category_column(train_quit, 'level')
# Out:
# junior    1949
# middle    1694
# senior     357
# Name: level, dtype: int64

# %% [markdown]
# В признаке "level" датафрейма "train_quit" наблюдается явный дисбаланс классов. Уровня "senior" заметно меньше остальных. Данный признак лучше кодировать OrdinalEncoder.

# %%
describe_category_column(train_quit, 'workload')
# Out:
# high       674
# low       1208
# medium    2118
# Name: workload, dtype: int64

# %% [markdown]
# В признаке "workload" датафрейма "train_quit" наблюдается явный дисбаланс классов. Уровня "medium" заметно больше остальных. Данный признак лучше кодировать OrdinalEncoder.

# %%
describe_category_column(train_quit, 'last_year_promo')
# Out:
# no     3887
# yes     113
# Name: last_year_promo, dtype: int64

# %% [markdown]
# В признаке "last_year_promo" датафрейма "train_quit" наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Данный признак лучше кодировать OneHotEncoder.

# %%
describe_category_column(train_quit, 'last_year_violations')
# Out:
# no     3455
# yes     545
# Name: last_year_violations, dtype: int64

# %% [markdown]
# В признаке "last_year_violations" датафрейма "train_quit" наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Данный признак лучше кодировать OneHotEncoder.

# %%
describe_category_column(train_quit, 'quit')
# Out:
# no     2872
# yes    1128
# Name: quit, dtype: int64

# %% [markdown]
# В признаке "quit" датафрейма "train_quit" (целевой признак) наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Данный признак лучше кодировать LabelEncoder.

# %%
describe_category_column(test_target_quit, 'quit')
# Out:
# no     1436
# yes     564
# Name: quit, dtype: int64

# %% [markdown]
# В признаке "quit" датафрейма "test_target_quit" (целевой признак) наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Данный признак лучше кодировать LabelEncoder.

# %% [markdown]
# #### Матрица корреляции признаков в тренировочной выборке

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(train_quit.drop('id', axis=1)
            .phik_matrix(interval_cols = ['employment_years', 
                                          'supervisor_evaluation', 
                                          'salary']), annot=True, cmap='coolwarm');
plt.title('Phi_K Correlation Matrix')
plt.show()

# %% [markdown]
# - Судя по тепловой карте, самая сильная прямая связь с целевым признаком `quit` наблюдается у входных признаков `employment_years` и `salary`.
# - Существует также связь между входными признаками `salary` и `workload`, `salary` и `level`, `level` и `employment_years`. Однако при таком значении индекса, это не мультиколлинеарность
# - Очень высоких корреляций (0.9 +) не видно, скорее всего мультиколлинеарности нет.

# %% [markdown]
# #### Портрет уволившегося сотрудника

# %% [markdown]
# Для составления уволившегося сотрудника рассмотрим рассмотрим распределение признаков в разрезе целевого с помощью графиков:

# %%
sns.countplot(x = 'dept', hue = 'quit', data = train_quit);

# %%
sns.countplot(x = 'level', hue = 'quit', data = train_quit);

# %%
sns.countplot(x = 'workload', hue = 'quit', data = train_quit);

# %%
sns.countplot(x = 'last_year_promo', hue = 'quit', data = train_quit);

# %%
sns.countplot(x = 'last_year_violations', hue = 'quit', data = train_quit);

# %%
sns.histplot(x = 'employment_years', hue = 'quit', data = train_quit, bins = 10);

# %%
sns.histplot(x = 'salary', hue = 'quit', data = train_quit, bins = 10);

# %%
display(train_quit.query('quit == "yes"').describe())
train_quit.query('quit == "no"').describe()
# Out:
#                   id  employment_years  supervisor_evaluation        salary
# count    1128.000000       1128.000000            1128.000000   1128.000000
# mean   544544.457447          1.844858               3.046099  23885.106383
# std    258059.498361          1.274920               0.973291   9351.599505
# min    100222.000000          1.000000               1.000000  12000.000000
# 25%    325073.000000          1.000000               3.000000  16800.000000
# 50%    545003.500000          1.000000               3.000000  22800.000000
# 75%    756296.000000          2.000000               4.000000  27600.000000
# max    999158.000000         10.000000               5.000000  79200.000000
#                   id  employment_years  supervisor_evaluation        salary
# count    2872.000000       2872.000000            2872.000000   2872.000000
# mean   555066.499652          4.430710               3.643106  37702.228412
# ...

# %% [markdown]
# Посмотрим также как распределился в долях наш целевой признак по категориальным признакам. Для этого напишим функцию:

# %%
def quit_prop(cat_column):
    quit_proportion_cat = pd.crosstab(index = train_quit[cat_column], columns = train_quit.quit, normalize = 'index')
    quit_proportion_cat = quit_proportion_cat.reset_index().set_index(cat_column)
    quit_proportion_cat.plot.bar(rot = 0, stacked = True).legend(loc = 'lower left');
    plt.title(f'Распределение данных по признаку "{cat_column}" в разрезе "quit"')
    plt.ylabel('Доли')
    plt.show()

# %%
quit_prop('dept')

# %%
quit_prop('level')

# %%
quit_prop('workload')

# %%
quit_prop('last_year_promo')

# %%
quit_prop('last_year_violations')

# %% [markdown]
# - Больше всего увольняются сотрудники оделов Продаж и Технологического. В этих же отделах соотношение уволенных к неуволенным наиболее большое.
# - Соотношение уволенных к неуволенным преобладает в уровне junior, но по количеству преобладет среднее звено.
# - Если говорить о загруженности, то больше всего увольняются сотрудники со средней загрузкой, однако соотношение уволенных к неуволенным - в низкой
# - Сотрудники, у которых было повышение в текущем году не увольняются.
# - Соотношение неуволенных к уволенным в разрезе наличия нарушений трудового договора за последний год бельше у тех кто нарушал. В количественном эквиваленте мало влияет на увольнение.
# - Средние зарплаты тех кто уволился заметно ниже тех, кто продолжил работать (23000 против 350000).
# - Анализ доли уволившихся в разрезе категориальных признаков показал:
#     - доля увлившихся примерно одинакова во всех отделах
#     - если рассматривать уровень занимаемой должности, то тут ожидаемо - доля уволившихся в позиции junior в значительной мере превышает (практически в 7 раз) доли уволившихся сотрудников, которые находились на уровне middle и senior (в этих категориях они практически равны)
#     - доля уволившихся со средним и высоким уровнем загруженности заметно меньше сотрудников с низким уровнем.
#     - доля уволившихся сотрудников, у ктороых было повышение за последний год ничтожна мала, хотя и не нулевая.
#     - среди же тех, у кого были нарушения договра за последний год - доля уволившихся почти в два раза превышает долю, у кого нарушений не было, но не превышает долю оставшихся.

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Нужно еще использовать относительные значения в описании портрета уволившегося сотрудника, прописать долю ушедших сотрудников.
#
# Например: 2000 работают в отделе hr и 200 из них уволилось, доля ушедших — 0.1; 300 работают в продажах и 150 из них уволилось, доля ушедших — 0.5. Важна именно доля

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b></b> Добавил сравнительный анализ в долях выше и добавил информацию в выводы. Спасибо за наводку, так признаки раскрылись более полно!
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# #### Влияние уровня удовлетворенности работой в компании сотрудника на его уход

# %% [markdown]
# Аналитики утверждают, что уровень удовлетворённости сотрудника работой в компании влияет на то, уволится ли сотрудник. Проверим это утверждение: визуализируем и сравним распределения признака job_satisfaction_rate для ушедших и оставшихся сотрудников. Используем данные с обоими целевыми признаками тестовой выборки.

# %%
# перевредем столбец "id" в индекс и уопядочим по индексу:
test_target_quit = test_target_quit.set_index('id').sort_index(ascending=True)

# %%
# объединим два тестовых датафрейма "test_target_job_satisfaction_rate" и test_target_quit" с целевыми признаками
test_target_join = test_target_job_satisfaction_rate.join(test_target_quit, how='left')
test_target_join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 100298 to 999029
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_satisfaction_rate  2000 non-null   float64
#  1   quit                   2000 non-null   object
# dtypes: float64(1), object(1)
# memory usage: 111.4+ KB

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Хорошо, что объединение происходит по `id`

# %%
sns.histplot(x = 'job_satisfaction_rate', hue = 'quit', data = test_target_join, bins = 10);

# %%
sns.boxplot(x = 'quit', y = 'job_satisfaction_rate', data = test_target_join);

# %% [markdown]
# Как видно из графиков, уровень удовлетворенности довольно сильно влияет на то, уволится ли сотрудник. Боксплот уровня удовлетворенности тех кто уволился находится в пределах от 0.2 до 0.5, пик - в районе 0.4. У тех, кто не уволился, уровень удовлетворенности гораздо выше.

# %% [markdown]
# Проведем также сравнение распределений признака job_satisfaction_rate для ушедших и оставшихся работников с использованием Т-теста.
# Проверим гипотезу:
#
# - **Н0** Нулевая гипотеза - средние значения признака job_satisfaction_rate уволившихся сотрудников и неуволившиеся равны
#
# - **Н1** Альтернативная гипотеза - средние двух выборок не равны

# %%
alpha = .05

results = st.ttest_ind(test_target_join.query('quit == "yes"')['job_satisfaction_rate'], 
                       test_target_join.query('quit == "no"')['job_satisfaction_rate'])

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 1.231122066517193e-104
# Отвергаем нулевую гипотезу

# %% [markdown]
# **Альтернативная гипотеза верна - средние значения признака job_satisfaction_rate уволившихся сотрудников и неуволившиеся  не равны.**

# %% [markdown]
# #### Вывод по итогам исследовательского анализа
#
# **Количественные признаки**
#
# - В признаке "employment_years" датафрейма "train_quit" выбросов и аномальных значений не наблюдается. Распределение напоминает распределение Пуассона. Понадобится масштабирование.
# - В признаке "supervisor_evaluation" датафрейма "train_quit" выбросов и аномальных значений не наблюдается. Есть значения за пределами "усов" боксплота, однако аномалиями или выбросами это назвать нельзя. Оставляем. Распределение напоминает распределение Пуассона. Понадобится масштабирование.
# - В признаке "salary" датафрейма "train_quit" выбросов и аномальных значений не наблюдается. Есть значения за пределами "усов" боксплота, однако аномалиями или выбросами это назвать нельзя. Оставляем. Распределение напоминает распределение Пуассона. Понадобится масштабирование.
#
# **Категориальные признаки**
#
# - В признаке "dept" датафрейма "train_quit" наблюдается явный дисбаланс классов. В частности выделяется "sales". Данный признак лучше кодировать OneHotEncoder
# - В признаке "level" датафрейма "train_quit" наблюдается явный дисбаланс классов. Уровня "senior" заметно меньше остальных. Данный признак лучше кодировать OrdinalEncoder.
# - В признаке "workload" датафрейма "train_quit" наблюдается явный дисбаланс классов. Уровня "medium" заметно больше остальных. Данный признак лучше кодировать OrdinalEncoder.
# - В признаке "last_year_promo" датафрейма "train_quit" наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Данный признак лучше кодировать OneHotEncoder.
# - В признаке "last_year_violations" датафрейма "train_quit" наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Данный признак лучше кодировать OneHotEncoder.
# - В признаке "quit" датафрейма "train_quit" (целевой признак) наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Данный признак лучше кодировать LabelEncoder.
# - В признаке "quit" датафрейма "test_target_quit" (целевой признак) наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Данный признак лучше кодировать LabelEncoder.
#
# **Матрицы корреляции**
#
# - Судя по тепловой карте, самая сильная прямая связь с целевым признаком `quit` наблюдается у входных признаков `employment_years` и `salary`.
# - Существует также связь между входными признаками `salary` и `workload`, `salary` и `level`, `level` и `employment_years`. Однако при таком значении индекса, это не мультиколлинеарность
# - Очень высоких корреляций (0.9 +) не видно, скорее всего мультиколлинеарности нет.
#
# **Портрет уволенного сотрудника**
#
# - Больше всего увольняются сотрудники оделов Продаж и Технологического. В этих же отделах соотношение уволенных к неуволенным наиболее большое.
# - Соотношение уволенных к неуволенным преобладает в уровне junior, но по количеству преобладет среднее звено.
# - Если говорить о загруженности, то больше всего увольняются сотрудники со средней загрузкой, однако соотношение уволенных к неуволенным - в низкой
# - Сотрудники, у которых было повышение в текущем году не увольняются.
# - Соотношение неуволенных к уволенным в разрезе наличия нарушений трудового договора за последний год бельше у тех кто нарушал. В количественном эквиваленте маол влияет на увольнение.
# - Средние зарплаты тех кто уволился заметно ниже тех, кто продолжил работать (23000 против 350000).
# - Анализ доли уволившихся в разрезе категориальных признаков показал:
#     - доля увлившихся примерно одинакова во всех отделах
#     - если рассматривать уровень занимаемой должности, то тут ожидаемо - доля уволившихся в позиции junior в значительной мере превышает (практически в 7 раз) доли уволившихся сотрудников, которые находились на уровне middle и senior (в этих категориях они практически равны)
#     - доля уволившихся со средним и высоким уровнем загруженности заметно меньше сотрудников с низким уровнем.
#     - доля уволившихся сотрудников, у ктороых было повышение за последний год ничтожна мала, хотя и не нулевая.
#     - среди же тех, у кого были нарушения договра за последний год - доля уволившихся почти в два раза превышает долю, у кого нарушений не было, но не превышает долю оставшихся.
#
# **Влияние уровня удовлетворенности работой в компании сотрудника на его уход**
#
# - Как видно из графиков, уровень удовлетворенности довольно сильно влияет на то, уволится ли сотрудник. Боксплот уровня удовлетворенности тех кто уволился находится в пределах от 0.2 до 0.5, пик - в районе 0.4. У тех, кто не уволился, уровень удовлетворенности гораздо выше.
# - средние значения признака job_satisfaction_rate уволившихся сотрудников и неуволившиеся не равны, что подтвердил стат.тест.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Хорошо. Добавлю, что сравнение распределений признака job_satisfaction_rate для ушедших и оставшихся работников можно провести с использованием стат теста

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b></b> Добавил стат.тест. Спасибо за подсказку!)
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# ### Шаг 4. Добавление нового входного признака

# %% [markdown]
# У нас остался один датафрейм, в котором столбец "id" не переведен индекс и датафрейм не упорядочен по индексу. Исправим это:

# %%
train_quit = train_quit.set_index('id').sort_index(ascending=True)
train_quit
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 100222       sales  junior   medium                 3              no
# 100459  purchasing  junior   medium                 3              no
# 100469   marketing  junior   medium                 1              no
# 100601  technology  middle     high                 4              no
# 100858       sales  junior   medium                 2              no
# ...            ...     ...      ...               ...             ...
# 998517  purchasing  middle      low                 5              no
# 999003          hr  middle      low                 3              no
# 999158  purchasing  junior   medium                 1              no
# 999835       sales  junior      low                 5              no
# 999915          hr  middle      low                 5              no
#
#        last_year_violations  supervisor_evaluation  salary quit
# id
# ...

# %% [markdown]
# Добавим признак `job_satisfaction_rate`, предсказанный для датафреймов `train_quit` и `test_features`:

# %%
train_quit['job_satisfaction_rate'] = grid_search.predict(train_quit)
train_quit.head()
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 100222       sales  junior   medium                 3              no
# 100459  purchasing  junior   medium                 3              no
# 100469   marketing  junior   medium                 1              no
# 100601  technology  middle     high                 4              no
# 100858       sales  junior   medium                 2              no
#
#        last_year_violations  supervisor_evaluation  salary quit  \
# id
# 100222                   no                      2   20400  yes
# 100459                   no                      3   21600  yes
# 100469                   no                      4   28800   no
# 100601                   no                      4   68400   no
# 100858                   no                      4   25200  yes
#
#         job_satisfaction_rate
# id
# 100222               0.340000
# 100459               0.311667
# 100469               0.630000
# ...

# %%
test_features['job_satisfaction_rate'] = grid_search.predict(test_features)
test_features.head()
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 100298          hr  junior      low                 2              no
# 100480   marketing  junior      low                 4              no
# 100503  purchasing  middle     high                 5              no
# 100610       sales  middle   medium                 5              no
# 100692       sales  middle     high                 6              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# 100298                   no                      4   19200
# 100480                   no                      4   16800
# 100503                   no                      4   55200
# 100610                   no                      4   43200
# 100692                   no                      4   48000
#
#         job_satisfaction_rate
# id
# 100298               0.831250
# 100480               0.852000
# 100503               0.746667
# 100610               0.810000
# ...

# %%
train_quit.duplicated().sum()
# Out:
# 1413

# %% [markdown]
# Получается, что из 4000 строк у нас 1413 являются явными дубликатами. Удалим их эти данные, чтобы не навредить будущей модели:

# %%
train_quit = train_quit.drop_duplicates()
train_quit.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Хорошо, признак job_satisfaction_rate добавлен в тренировочную и тестовую выборки, а значения предсказаны с помощью лучшей модели регрессии, обученной в прошлой части задачи

# %% [markdown]
# ### Шаг 5. Подготовка данных

# %% [markdown]
# Перечислим особенности данных:
#
# 1. Целевой признак — `quit`.
# 2. Три признака: `dept`, `last_year_promo`, `last_year_violations`, — нужно кодировать с помощью OneHotEncoder.
# 3. Два признака: `level`, `workload` — нужно кодировать с помощью OrdinalEncoder.
# 4. Количественные признаки `employment_years`, `supervisor_evaluation`, `salary`, `job_satisfaction_rate`.
# 5. Необходима обработка пропусков.

# %% [markdown]
# Так как целевой признак у нас представлен двумя категориями 'yes'/'no', а для расчета метрик необходимы значения 1/0, воспользуемся кодировкой LabelEncoder:

# %%
# Инициалиируем LabelEncoder для кодировки целевого признака:
label_encoder = LabelEncoder()
#Обучим и преобразуем целевой признак в датафрейме "train_quit":
label_encoder.fit(train_quit['quit'])
label_encoder.classes_ = np.array(['no', 'yes'])
train_quit['quit'] = label_encoder.transform(train_quit['quit'])
train_quit.head()
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 100222       sales  junior   medium                 3              no
# 100459  purchasing  junior   medium                 3              no
# 100469   marketing  junior   medium                 1              no
# 100601  technology  middle     high                 4              no
# 100858       sales  junior   medium                 2              no
#
#        last_year_violations  supervisor_evaluation  salary  quit  \
# id
# 100222                   no                      2   20400     1
# 100459                   no                      3   21600     1
# 100469                   no                      4   28800     0
# 100601                   no                      4   68400     0
# 100858                   no                      4   25200     1
#
#         job_satisfaction_rate
# id
# 100222               0.340000
# 100459               0.311667
# 100469               0.630000
# ...

# %%
#Обучим и преобразуем целевой признак в датафрейме "test_target_quit":
#label_encoder.fit(test_target_quit['quit'])
#label_encoder.classes_ = np.array(['no', 'yes'])
test_target_quit['quit'] = label_encoder.transform(test_target_quit['quit'])
test_target_quit.head()
# Out:
#         quit
# id
# 100298     0
# 100480     0
# 100503     0
# 100610     0
# 100692     0

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Чтобы не было утечки в тестовую выборку обучать `LabelEncoder()` следует на тренировочной выборке, а потом метод `transform` уже применять ко всем выборкам. Исправь пожалуйста
#  </div>

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b></b> Все поправил, спасибо!
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %%
train_quit.sort_index(ascending=True)
test_features.sort_index(ascending=True)
test_target_quit.sort_index(ascending=True)
# Out:
#         quit
# id
# 100298     0
# 100480     0
# 100503     0
# 100610     0
# 100692     0
# ...      ...
# 997290     0
# 998548     1
# 998762     1
# 998900     0
# 999029     1
#
# [2000 rows x 1 columns]

# %%
# проведем разметку целевого и входных признаков на тренировочной и тестовой выборках:
X_train_2 = train_quit.drop(['quit'], axis=1)
y_train_2 = train_quit['quit']

X_test_2 = test_features
y_test_2 = test_target_quit['quit']

# создаём списки с названиями признаков
ohe_columns_2 = ['dept', 'last_year_promo', 'last_year_violations']
ord_columns_2 = ['level', 'workload']
num_columns_2 = ['employment_years', 'supervisor_evaluation', 'salary', 'job_satisfaction_rate']

# создаём пайплайн для подготовки признаков из списка ohe_columns: заполнение пропусков и OHE-кодирование
# SimpleImputer + OHE
ohe_pipe_2 = Pipeline(
    [
        (
            'simpleImputer_ohe_nan_1', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'simpleImputer_ohe_nan_spase', 
            SimpleImputer(missing_values=" ", strategy='constant', fill_value=np.nan)
        ),
        (
            'simpleImputer_ohe_nan_2', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ohe', 
            OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False)
        )
    ]
)

# cоздаём пайплайн для подготовки признаков из списка ord_columns: заполнение пропусков и Ordinal-кодирование
# SimpleImputer + OE
ord_pipe_2 = Pipeline(
    [
        (
            'simpleImputer_before_ord_nan_1', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'simpleImputer_before_ord_space', 
            SimpleImputer(missing_values=" ", strategy='constant', fill_value=np.nan)
        ),
        (
            'simpleImputer_before_ord_nan_2', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ord',  
            OrdinalEncoder(
                categories=[
                    ['junior', 'middle', 'senior'],
                    ['high', 'medium', 'low']
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
        (
            'simpleImputer_after_ord', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
)

# создаём общий пайплайн для подготовки данных
data_preprocessor_2 = ColumnTransformer(
    [
        ('ohe', ohe_pipe_2, ohe_columns_2),
        ('ord', ord_pipe_2, ord_columns_2),
        ('num', MinMaxScaler(), num_columns_2)
    ], 
    remainder='passthrough'
)

# %% [markdown]
# #### Вывод по итогам предобрботки данных
#
# Для подготовки данных мы:
# - перевели столбец "id" в индекс для удобства и отсортировали датафреймы по индексу с целью упорядочить данные в тестовых выборках (входные и целевой признаки);
# - обучили и преобразовали целевой признак в датафрейме train_quit и "test_target_quit";
# - провели разметку целевого и входных признаков на тренировочной и тестовой выборках;
# - обработали пропуски nan  и пробелы с помощью SimpleImputer;
# - создали пайплайн с использованием ColumnTransformer. Количественные и категориальные данные обработаны в пайплайне раздельно.

# %% [markdown]
# ### Шаг 6. Обучение модели

# %%
# создаем итоговый пайплайн: подготовка данных и модель
pipe_final_2 = Pipeline(
    [
        ('preprocessor', data_preprocessor_2),
        ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
    ]
)

# создаем список моделей с перебором параметров:

param_grid_2 = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 30),
        'models__max_features': range(2, 30),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 10),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели SVC()
#    {
#        'models': [SVC(random_state=RANDOM_STATE, 
#                       probability=True)], 
#        'models__kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
#        'models__degree': range(1, 3), 
#        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
#
#    }
]

# %%
# %%time

grid_search_2 = GridSearchCV(
    pipe_final_2, 
    param_grid_2, 
    cv=5,
    scoring='roc_auc',
    n_jobs=-1
)
grid_search_2.fit(X_train_2, y_train_2)
# Out:
# CPU times: user 6min 27s, sys: 525 ms, total: 6min 28s
# Wall time: 6min 28s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ohe',
#                                                                          Pipeline(steps=[('simpleImputer_ohe_nan_1',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('simpleImputer_ohe_nan_spase',
#                                                                                           SimpleImputer(fill_value=nan,
#                                                                                                         missing_values=' ',
# ...

# %%
print('Лучшая модель и её параметры:\n\n', grid_search_2.best_estimator_)
print ('Метрика лучшей модели на кроссвалидационной выборке:', grid_search_2.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe_nan_1',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('simpleImputer_ohe_nan_spase',
#                                                                    SimpleImputer(fill_value=nan,
#                                                                                  missing_values=' ',
#                                                                                  strategy='constant')),
#                                                                   ('simpleImputer_ohe_nan_2',
# ...

# %%
y_pred_2 = grid_search_2.predict_proba(X_test_2)[:,1]
print(f'Метрика ROC-AUC на тестовой выборке: {round(roc_auc_score(y_test_2, y_pred_2), 2)}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.91

# %% [markdown]
# #### Вывод по итогам обучения модели
#
# В процессе обучения модели:
# - создали итоговый пайплайн: подготовка данных и модель;
# - создали пайплайн для поиска лучшей модели из: DecisionTreeClassifier(), KNeighborsClassifier() и LogisticRegression()
# - для каждой модели подобрали как минимум один гиперпараметр. Данные масштабированы как минимум двумя методами
# - для выбора лучшей модели использовали метрику ROC-AUC так как она оценивает качество решений модели в наиболее общем виде, учитывая все возможные пороговые значения, ее можно использовать в случае, когда объектов с одним значением целевого признака больше, чем с другими (как раз наш случай).
# - По итогам, лучшей моделью определена модель DecisionTreeClassifier с гиперпараметрами max_depth=4, max_features=12.
# - При этом ее метрика на тестовой выборке составила - 0.91.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# На тестовой выборке получено хорошее качество)

# %% [markdown]
# ### Шаг 7. Выводы

# %% [markdown]
# - В результате проведенных предобработки, исследовательских анализов, подготовки данных, создания пайплайна, была была построена  модель DecisionTreeClassifier с гиперпараметрами max_depth=4, max_features=12.
# - Данная модель сможет предсказать вероятность ухода сотрудника на основе данных заказчика. По результатам полученных прогнозных значений, заказчик сможет предсказывать отток сотрудников, что поможет, в конечном итоге оказать положительное влияние на бизнес, так как внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Приятно видеть общий вывод)

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **В данном проекте было определено две цели:**
#
# **1. Построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.**
#
# **2. Построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.**
#
# **Для решения первой задачи были предоставлены:**
#
# Тренировочная выборка: `train_job_satisfaction_rate.csv`
#
# Входные признаки тестовой выборки: `test_features.csv`
#
# Целевой признак тестовой выборки: `test_target_job_satisfaction_rate.csv`
#
# - `id` — уникальный идентификатор сотрудника;
# - `dept` — отдел, в котором работает сотрудник;
# - `level` — уровень занимаемой должности;
# - `workload` — уровень загруженности сотрудника;
# - `employment_years` — длительность работы в компании (в годах);
# - `last_year_promo` — показывает, было ли повышение за последний год;
# - `last_year_violations` — показывает, нарушал ли сотрудник трудовой договор за последний год;
# - `supervisor_evaluation` — оценка качества работы сотрудника, которую дал руководитель;
# - `salary` — ежемесячная зарплата сотрудника;
# - `job_satisfaction_rate` — уровень удовлетворённости сотрудника работой в компании, целевой признак.
#
# **Для решения второй задачи:**
#
# Тренировочная выборка: `train_quit.csv`
#
# Входные признаки тестовой выборки те же, что и в прошлой задаче: `test_features.csv`
#
# Целевой признак тестовой выборки: `test_target_quit.csv`
#
# **В ходе предобработки данных было проведено:**
#
# - Проверка на неявные дубликаты показала их отсутствие.
# - Исправили орфографическую ошибку - заменили `sinior` на `senior`  в столбцах `level` датафреймов `train_job_satisfaction_rate`, `test_features` и `train_quit`.
# - Обнаружили "пропуски" в виде пробелов в столбцах `dept` и `workload` датафрейма `test_features` - обработали их в пайпланее вместе с nan.
#
# **В ходе исследовательского анализа были определены следущие факты:**
#
# **Количественные признаки**
#
# - В признаке "employment_years" датафрейма "train_job_satisfaction_rate" выбросов и аномальных значений не наблюдается. Распределение напоминает распределение Пуассона. Понадобится масштабирование.
# - В признаке "supervisor_evaluation" датафрейма "train_job_satisfaction_rate" выбросов и аномальных значений не наблюдается. Есть значения за пределами "усов" боксплота, однако аномалиями или выбросами это назвать нельзя. Оставляем. Распределение напоминает распределение Пуассона. Понадобится масштабирование.
# - В признаке "salary" датафрейма "train_job_satisfaction_rate" выбросов и аномальных значений не наблюдается. Есть значения за пределами "усов" боксплота, однако аномалиями или выбросами это назвать нельзя. Оставляем. Распределение напоминает распределение Пуассона. Понадобится масштабирование.
# - В признаке "job_satisfaction_rate" датафрейма "train_job_satisfaction_rate" выбросов и аномальных значений не наблюдается. Распределение напоминает распределение Пуассона
# - В признаке "employment_years" датафрейма "test_features" выбросов и аномальных значений не наблюдается. Распределение напоминает распределение Пуассона. Понадобится масштабирование.
# - В признаке "supervisor_evaluation" датафрейма "test_features" выбросов и аномальных значений не наблюдается. Есть значения за пределами "усов" боксплота, однако аномалиями или выбросами это назвать нельзя. Оставляем. Распределение напоминает распределение Пуассона. Понадобится масштабирование.
# - В признаке "salary" датафрейма "test_features" выбросов и аномальных значений не наблюдается. Есть значения за пределами "усов" боксплота, однако аномалиями или выбросами это назвать нельзя. Оставляем. Распределение напоминает распределение Пуассона. Понадобится масштабирование.
# - В признаке "job_satisfaction_rate" датафрейма "test_target_job_satisfaction_rate" выбросов и аномальных значений не наблюдается. Распределение напоминает распределение Пуассона
# - В признаке "employment_years" датафрейма "train_quit" выбросов и аномальных значений не наблюдается. Распределение напоминает распределение Пуассона. Понадобится масштабирование.
# - В признаке "supervisor_evaluation" датафрейма "train_quit" выбросов и аномальных значений не наблюдается. Есть значения за пределами "усов" боксплота, однако аномалиями или выбросами это назвать нельзя. Оставляем. Распределение напоминает распределение Пуассона. Понадобится масштабирование.
# - В признаке "salary" датафрейма "train_quit" выбросов и аномальных значений не наблюдается. Есть значения за пределами "усов" боксплота, однако аномалиями или выбросами это назвать нельзя. Оставляем. Распределение напоминает распределение Пуассона. Понадобится масштабирование.
#
#
# **Категориальные признаки**
#
# - В признаке "dept" датафрейма "train_job_satisfaction_rate" наблюдается явный дисбаланс классов. В частности выделяется "sales". Возможно понадобится семплирование. Данный признак лучше кодировать OneHotEncoder
# - В признаке "level" датафрейма "train_job_satisfaction_rate" наблюдается явный дисбаланс классов. Уровня "senior" заметно меньше остальных. Возможно понадобится семплирование. Данный признак лучше кодировать OrdinalEncoder.
# - В признаке "workload" датафрейма "train_job_satisfaction_rate" наблюдается явный дисбаланс классов. Уровня "medium" заметно больше остальных. Возможно понадобится семплирование. Данный признак лучше кодировать OrdinalEncoder.
# - В признаке "last_year_promo" датафрейма "train_job_satisfaction_rate" наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Возможно понадобится семплирование. Данный признак лучше кодировать OneHotEncoder.
# - В признаке "last_year_violations" датафрейма "train_job_satisfaction_rate" наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Возможно понадобится семплирование. Данный признак лучше кодировать OneHotEncoder.
# - В признаке "dept" датафрейма "test_features" наблюдается явный дисбаланс классов. В частности выделяется "sales". Возможно понадобится семплирование. Данный признак лучше кодировать OneHotEncoder
# - В признаке "level" датафрейма "test_features" наблюдается явный дисбаланс классов. Уровня "senior" заметно меньше остальных. Возможно понадобится семплирование. Данный признак лучше кодировать OrdinalEncoder.
# - В признаке "workload" датафрейма "test_features" наблюдается явный дисбаланс классов. Уровня "medium" заметно больше остальных. Возможно понадобится семплирование. Данный признак лучше кодировать OrdinalEncoder.
# - В признаке "last_year_promo" датафрейма "test_features" наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Возможно понадобится семплирование. Данный признак лучше кодировать OneHotEncoder.
# - В признаке "last_year_violations" датафрейма "test_features" наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Возможно понадобится семплирование. Данный признак лучше кодировать OneHotEncoder.
# - В признаке "dept" датафрейма "train_quit" наблюдается явный дисбаланс классов. В частности выделяется "sales". Данный признак лучше кодировать OneHotEncoder
# - В признаке "level" датафрейма "train_quit" наблюдается явный дисбаланс классов. Уровня "senior" заметно меньше остальных. Данный признак лучше кодировать OrdinalEncoder.
# - В признаке "workload" датафрейма "train_quit" наблюдается явный дисбаланс классов. Уровня "medium" заметно больше остальных. Данный признак лучше кодировать OrdinalEncoder.
# - В признаке "last_year_promo" датафрейма "train_quit" наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Данный признак лучше кодировать OneHotEncoder.
# - В признаке "last_year_violations" датафрейма "train_quit" наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Данный признак лучше кодировать OneHotEncoder.
# - В признаке "quit" датафрейма "train_quit" (целевой признак) наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Данный признак лучше кодировать LabelEncoder.
# - В признаке "quit" датафрейма "test_target_quit" (целевой признак) наблюдается явный дисбаланс классов. Уровня "no" заметно больше остальных. Данный признак лучше кодировать LabelEncoder.
#
#
# **Матрицы корреляции**
#
# - Судя по тепловой карте, самая сильная прямая связь с целевым признаком `job_satisfaction_rate` наблюдается у входных признаков `supervisor_evaluation` и `last_year_violations`.
# - Существует также связь между входными признаками `salary` и `workload`, `salary` и `level`, `level` и `employment_years`. Однако при таком значении индекса, это не мультиколлинеарность
# - Судя по тепловой карте, самая сильная прямая связь с целевым признаком `quit` наблюдается у входных признаков `employment_years` и `salary`.
# - Существует также связь между входными признаками `salary` и `workload`, `salary` и `level`, `level` и `employment_years`. Однако при таком значении индекса, это не мультиколлинеарность
# - Очень высоких корреляций (0.9 +) не видно, скорее всего мультиколлинеарности нет.
#
# **Портрет уволенного сотрудника**
#
# - Больше всего увольняются сотрудники оделов Продаж и Технологического. В этих же отделах соотношение уволенных к неуволенным наиболее большое.
# - Соотношение уволенных к неуволенным преобладает в уровне junior, но по количеству преобладет среднее звено.
# - Если говорить о загруженности, то больше всего увольняются сотрудники со средней загрузкой, однако соотношение уволенных к неуволенным - в низкой
# - Сотрудники, у которых было повышение в текущем году не увольняются.
# - Соотношение неуволенных к уволенным в разрезе наличия нарушений трудового договора за последний год бельше у тех кто нарушал. В количественном эквиваленте маол влияет на увольнение.
# - Средние зарплаты тех кто уволился заметно ниже тех, кто продолжил работать (23000 против 350000).
# - Анализ доли уволившихся в разрезе категориальных признаков показал:
#     - доля увлившихся примерно одинакова во всех отделах
#     - если рассматривать уровень занимаемой должности, то тут ожидаемо - доля уволившихся в позиции junior в значительной мере превышает (практически в 7 раз) доли уволившихся сотрудников, которые находились на уровне middle и senior (в этих категориях они практически равны)
#     - доля уволившихся со средним и высоким уровнем загруженности заметно меньше сотрудников с низким уровнем.
#     - доля уволившихся сотрудников, у ктороых было повышение за последний год ничтожна мала, хотя и не нулевая.
#     - среди же тех, у кого были нарушения договра за последний год - доля уволившихся почти в два раза превышает долю, у кого нарушений не было, но не превышает долю оставшихся.
#
# **Влияние уровня удовлетворенности работой в компании сотрудника на его уход**
#
# - Как видно из графиков, уровень удовлетворенности довольно сильно влияет на то, уволится ли сотрудник. Боксплот уровня удовлетворенности тех кто уволился находится в пределах от 0.2 до 0.5, пик - в районе 0.4. У тех, кто не уволился, уровень удовлетворенности гораздо выше.
# - средние значения признака job_satisfaction_rate уволившихся сотрудников и неуволившиеся не равны, что подтвердил стат.тест.
#
# **В ходе подготовки данных:**
#
# - **Задача 1**
#     - перевели столбец "id" в индекс для удобства и отсортировали датафреймы по индексу с целью упорядочить данные в тестовых выборках (входные и целевой признаки);
#     - убрали возникшие дубликаты из тренировочной выборки, чтобы избавиться от негативного воздействия их на модель;
#     - провели разметку целевого и входных признаков на тренировочной и тестовой выборках;
#     - обработали пропуски nan  и пробелы с помощью SimpleImputer;
#     - создали пайплайн с использованием ColumnTransformer. Количественные и категориальные данные обработаны в пайплайне раздельно.
# - **Задача 2**
#     - перевели столбец "id" в индекс для удобства и отсортировали датафреймы по индексу с целью упорядочить данные в тестовых выборках (входные и целевой признаки);
#     - убрали возникшие дубликаты из тренировочной выборки, чтобы избавиться от негативного воздействия их на модель;
#     - обучили и преобразовали целевой признак в датафрейме train_quit и "test_target_quit";
#     - провели разметку целевого и входных признаков на тренировочной и тестовой выборках;
#     - обработали пропуски nan  и пробелы с помощью SimpleImputer;
#     - создали пайплайн с использованием ColumnTransformer. Количественные и категориальные данные обработаны в пайплайне раздельно.
#
# **В ходе обучения модели:**
#
# - **Задача 1**
#     - В результате проведенных предобработки, исследовательских анализов, подготовки данных, создания пайплайна, была была построена  модель DecisionTreeRegressor с гиперпараметрами max_depth=17, min_samples_split=7.
# - **Задача 2**
#     - В результате проведенных предобработки, исследовательских анализов, подготовки данных, создания пайплайна, была была построена  модель DecisionTreeClassifier с гиперпараметрами max_depth=4, max_features=12.
#
#
# - **Данная модели, работая в паре, смогут предсказать вероятность ухода сотрудника на основе данных заказчика. По результатам полученных прогнозных значений, заказчик сможет предсказывать отток сотрудников, что поможет, в конечном итоге оказать положительное влияние на бизнес, так как внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник. Стоит отметить несколько важных факторов и предложений для бизнеса:**
#
#     - 💡 необходимо поработать над повышением уровня удовлетворенности сотрудников, так как чем выше уровень удовлетворенности - тем меньше вероятность увольнения;
#     - 💡 повысить уровень удовлетворенности поможет развитие сотрудников, необходимо дать возможность для обучения, повышения уровня с junior до middle;
#     - 💡 необходимо уделить внимание уровню загруженности - слишком маленькая совсем не способствуте долгосрочному выстраиванию трудовых отношений, впрочем как и явный дисбаланс между работой и личным временем;
#     - 💡 оценка качества работы сотрудника должна производится на регулярной основе и это напрямую должно влиять на пересмотр заработной платы.
#
# **В целом, основная цель проекта достигнута.**
#
# ✔️ **Были разаработаны две модели,  одна из которых предскажет уровень удовлетворенности сотрудника, а вторая - его уход из компании.**
#
# ✔️ **Были предложены решения, которое позволят сохранить важных сотрудников и минимизировать рискидля бизнеса.**

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера (общий вывод по проекту) <a class="tocSkip"> </h2>
#
#
# У меня сложилось хорошее общее впечатление о проекте, тебе удалось неплохо справиться с этим проектом. Молодец! Подготовлены данные для анализа, изучен каждый параметр. Все красиво визуализировано, построено несколько моделей регрессии/ классификации и оценено их качество. Осмысленная аналитика и дельная модельная работа - многое удалось как надо)
#
# Отмечу отдельные положительные моменты проекта🙂:
#
# - в ходе проекта встречались  функции, помогающие избавиться от дублирования кода;
# - много красивых визуализаций в проекте и хорошая интерпретация;
# - при обучении моделей использованы пайплайны, кросс-валидация и поиск гиперпараметров.
#
# Есть несколько моментов всего, на которые стоит ещё раз взглянуть, я указал их в моих комментариях по ходу проекта. Предлагаю тебе доработать проект по моим комментариям, чтобы довести его до совершенства.
#
#
#
# </div>

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Еще раз - спасибо за ревью, постарался исправить все ошибки и учесть все твои подсказки)))
# </div>
#
# <br/>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера (итоговый вывод по проекту) <a class="tocSkip"> </h2>
#
#
#
# Теперь почти идеально. Принимаю работу)
#
# Если хочешь лучше разобраться в ML, то могу посоветовать тебе:
#
# - Открытый курс машинного обучения: https://habr.com/ru/company/ods/blog/322626/
#
# - Книжка от ШАД: https://academy.yandex.ru/handbook/ml/
#
# - Также рекомендую лекции от Andrew Ng: https://www.youtube.com/watch?v=PPLop4L2eGk&list=PLLssT5z_DsK-h9vYZkQkYNWcItqhlRJLN
# - Избежать утечки данных при кросс-валидации тебе поможет <a href="https://towardsdatascience.com/pipeline-columntransformer-and-featureunion-explained-f5491f815f">конвеерная обработка данных</a>.
#
# - Не все признаки приносят пользу при моделировании. Инструмент <a href="https://proglib.io/p/feature-selector">FeatureSelector</a> поможет тебе отобрать важные признаки и избавит от ручной обработки.  Также можешь посмотреть статью на <a href="https://www.kaggle.com/code/prashant111/comprehensive-guide-on-feature-selection/notebook">Kaggle</a> (она сложнее).
#
#
# В этом проекте были отработаны все моменты.
#
# Успехов тебе в следующем спринте!
#
# Рад был помочь тебе)
#
# </div>
